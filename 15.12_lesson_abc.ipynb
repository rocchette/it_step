# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from datetime import date,timedelta

# %%
df=pd.read_csv('data.csv.zip', encoding="ISO-8859-1")

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.CustomerID.isna().sum()
# Out:
# 135080

# %%
df=df.fillna(0)

# %%
df.CustomerID.isna().sum()
# Out:
# 0

# %%
df_1=df.query('CustomerID>0')
df_1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df_1.Quantity.describe()
# Out:
# count    406829.000000
# mean         12.061303
# std         248.693370
# min      -80995.000000
# 25%           2.000000
# 50%           5.000000
# 75%          12.000000
# max       80995.000000
# Name: Quantity, dtype: float64

# %%
df_1.Quantity.plot()
# Out:
# <AxesSubplot:>

# %%
df_1.UnitPrice.describe()
# Out:
# count    406829.000000
# mean          3.460471
# std          69.315162
# min           0.000000
# 25%           1.250000
# 50%           1.950000
# 75%           3.750000
# max       38970.000000
# Name: UnitPrice, dtype: float64

# %%
df_1.query('UnitPrice==38970')
# Out:
#        InvoiceNo StockCode Description  Quantity      InvoiceDate  UnitPrice  \
# 222681   C556445         M      Manual        -1  6/10/2011 15:31    38970.0
#
#         CustomerID         Country
# 222681     15098.0  United Kingdom

# %%
df_1.UnitPrice.plot()
# Out:
# <AxesSubplot:>

# %%
df_2=df_1.query('Quantity>0')
df_2
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df_2.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  397924.000000  397924.000000  397924.000000
# mean       13.021823       3.116174   15294.315171
# std       180.420210      22.096788    1713.169877
# min         1.000000       0.000000   12346.000000
# 25%         2.000000       1.250000   13969.000000
# 50%         6.000000       1.950000   15159.000000
# 75%        12.000000       3.750000   16795.000000
# max     80995.000000    8142.750000   18287.000000

# %%
df_2.Quantity.plot()
# Out:
# <AxesSubplot:>

# %%
df_2.UnitPrice.plot()
# Out:
# <AxesSubplot:>

# %%
df_2=df_2.query('UnitPrice<5000')

# %%
df_2=df_2.query('Quantity<10000')

# %%
df_2
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df_2['total_sum']=df_2.UnitPrice*df_2.Quantity
# Out:
# C:\Users\st\AppData\Local\Temp\ipykernel_184\1077486258.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2['total_sum']=df_2.UnitPrice*df_2.Quantity

# %%
df_abc = df_2.groupby('CustomerID', as_index = False).agg({'total_sum': 'sum'}).sort_values('total_sum', ascending = False)

# %%
df_abc
# Out:
#       CustomerID  total_sum
# 1688     14646.0  280206.02
# 4200     18102.0  259657.30
# 3727     17450.0  194550.79
# 1878     14911.0  143825.06
# 54       12415.0  124914.53
# ...          ...        ...
# 4097     17956.0      12.75
# 3013     16454.0       6.90
# 1792     14792.0       6.20
# 3216     16738.0       3.75
# 3007     16446.0       2.90
#
# [4337 rows x 2 columns]

# %%
total_sum=df_abc.total_sum.sum()
total_sum
# Out:
# 8657611.954

# %%
df_abc['share_of_total']=df_abc.total_sum/total_sum*100

# %%
df_abc
# Out:
#       CustomerID  total_sum  share_of_total
# 1688     14646.0  280206.02        3.236528
# 4200     18102.0  259657.30        2.999179
# 3727     17450.0  194550.79        2.247165
# 1878     14911.0  143825.06        1.661256
# 54       12415.0  124914.53        1.442829
# ...          ...        ...             ...
# 4097     17956.0      12.75        0.000147
# 3013     16454.0       6.90        0.000080
# 1792     14792.0       6.20        0.000072
# 3216     16738.0       3.75        0.000043
# 3007     16446.0       2.90        0.000033
#
# [4337 rows x 3 columns]

# %%
df_abc['cum_sum']=df_abc.share_of_total.cumsum()

# %%
df_abc
# Out:
#       CustomerID  total_sum  share_of_total     cum_sum
# 1688     14646.0  280206.02        3.236528    3.236528
# 4200     18102.0  259657.30        2.999179    6.235707
# 3727     17450.0  194550.79        2.247165    8.482872
# 1878     14911.0  143825.06        1.661256   10.144127
# 54       12415.0  124914.53        1.442829   11.586956
# ...          ...        ...             ...         ...
# 4097     17956.0      12.75        0.000147   99.999772
# 3013     16454.0       6.90        0.000080   99.999852
# 1792     14792.0       6.20        0.000072   99.999923
# 3216     16738.0       3.75        0.000043   99.999967
# 3007     16446.0       2.90        0.000033  100.000000
#
# [4337 rows x 4 columns]

# %%
df_abc['abc'] = np.where(df_abc['cum_sum']<80, 'A', np.where((df_abc['cum_sum']<95), 'B', 'C'))

# %%
df_abc
# Out:
#       CustomerID  total_sum  share_of_total     cum_sum abc
# 1688     14646.0  280206.02        3.236528    3.236528   A
# 4200     18102.0  259657.30        2.999179    6.235707   A
# 3727     17450.0  194550.79        2.247165    8.482872   A
# 1878     14911.0  143825.06        1.661256   10.144127   A
# 54       12415.0  124914.53        1.442829   11.586956   A
# ...          ...        ...             ...         ...  ..
# 4097     17956.0      12.75        0.000147   99.999772   C
# 3013     16454.0       6.90        0.000080   99.999852   C
# 1792     14792.0       6.20        0.000072   99.999923   C
# 3216     16738.0       3.75        0.000043   99.999967   C
# 3007     16446.0       2.90        0.000033  100.000000   C
#
# [4337 rows x 5 columns]

# %%
df_abc.query('abc=="A"')
# Out:
#       CustomerID  total_sum  share_of_total    cum_sum abc
# 1688     14646.0  280206.02        3.236528   3.236528   A
# 4200     18102.0  259657.30        2.999179   6.235707   A
# 3727     17450.0  194550.79        2.247165   8.482872   A
# 1878     14911.0  143825.06        1.661256  10.144127   A
# 54       12415.0  124914.53        1.442829  11.586956   A
# ...          ...        ...             ...        ...  ..
# 1384     14229.0    1547.20        0.017871  79.926841   A
# 1731     14704.0    1546.91        0.017868  79.944708   A
# 3259     16790.0    1545.62        0.017853  79.962561   A
# 788      13397.0    1544.13        0.017836  79.980397   A
# 2465     15701.0    1542.14        0.017813  79.998209   A
#
# [1163 rows x 5 columns]

# %%
1163/4337 #26% клиентов приносят 80% прибыли
# Out:
# 0.26815771270463457
